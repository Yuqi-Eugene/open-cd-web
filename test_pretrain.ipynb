# %%
# just a test for pretrain model using changer
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

from opencd.apis import OpenCDInferencer
import torch

# %%
# Load models into memory
inferencer = OpenCDInferencer(model='work_dirs/wj1024_changerex_r18/changer_ex_r18_512x512_40k_wj1024.py', 
weights='work_dirs/wj1024_changerex_r18/best_mFscore_iter_40000.pth', 
device='cpu',
classes=('unchanged', 'changed'), 
palette=[[0, 0, 0], [255, 255, 255]])
print(1+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Load models into memory
# ----> 2 inferencer = OpenCDInferencer(model='work_dirs/wj1024_changerex_r18/changer_ex_r18_512x512_40k_wj1024.py',
#       3 weights='work_dirs/wj1024_changerex_r18/best_mFscore_iter_40000.pth',
#       4 device='cpu',
#       5 classes=('unchanged', 'changed'),
#       6 palette=[[0, 0, 0], [255, 255, 255]],
#       7 type='MultiImgLoadImageFromFile',
#       8 imdecode_backend='tifffile')
#       9 print(1+1)
#
# File ~/Downloads/Coding/Geospatial/open-cd/opencd/apis/opencd_inferencer.py:41, in OpenCDInferencer.__init__(self, classes, palette, dataset_name, scope, **kwargs)
#      35 def __init__(self,
#      36              classes: Optional[Union[str, List]] = None,
#      37              palette: Optional[Union[str, List]] = None,
# ...

# %%
# Inference
inferencer([['data/wj1024_split/test/A/2023_2024_2179.tif', 'data/wj1024_split/test/B/2023_2024_2179.tif']], show=False, out_dir='output/')
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [ WARN:0@43.683] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 33550 (0x830e) encountered
# [ WARN:0@43.683] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 33922 (0x8482) encountered
# [ WARN:0@43.683] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34735 (0x87af) encountered
# [ WARN:0@43.683] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 34737 (0x87b1) encountered
# [ WARN:0@43.699] global grfmt_tiff.cpp:122 TIFF_Warning TIFFReadDirectory: Unknown field with tag 33550 (0x830e) encountered
# ...
